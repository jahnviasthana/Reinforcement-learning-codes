# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnviasthana/Reinforcement-learning-codes/blob/main/correlation_practical1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([1,2,3,4,5])

# %%
print(np.corrcoef(x,y))
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([-1,-2,-3,-4,-5])
print(np.corrcoef(x,y))
plt.plot(x,y)
plt.scatter(x,y)
# Out:
# [[ 1. -1.]
#  [-1.  1.]]

# %%
import numpy as np
x=np.array([1,2,3,4,5])
y=np.array([0,0,0,0,0])
print(np.corrcoef(x,y))
# Out:
# [[ 1. nan]
#  [nan nan]]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2829: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /usr/local/lib/python3.10/dist-packages/numpy/lib/function_base.py:2830: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)

# %%
x1 = np.random.randint(0,50,100)

y1 = np.random.randint(150,200,100)
print(np.corrcoef(x1,y1))
plt.scatter(x1,y1)
plt.show()
# Out:
# [[ 1.         -0.00965439]
#  [-0.00965439  1.        ]]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = {
    "d1" :[11,3,31,3,54,34],
    "d2" :[5,42,1,34,25,23] ,
    "d3" :[10,31,12,3,53,3],
    "d4" :[58,42,21,43,5,3]
 }
df = pd.DataFrame(data)
print(data)
print(df.corr())
corr = df.corr(method = 'pearson')
corr
plt.figure(figsize=(5,2), dpi =200)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.5)
plt.show()
# Out:
# {'d1': [11, 3, 31, 3, 54, 34], 'd2': [5, 42, 1, 34, 25, 23], 'd3': [10, 31, 12, 3, 53, 3], 'd4': [58, 42, 21, 43, 5, 3]}
#           d1        d2        d3        d4
# d1  1.000000 -0.305756  0.501165 -0.863835
# d2 -0.305756  1.000000  0.274538  0.002409
# d3  0.501165  0.274538  1.000000 -0.304495
# d4 -0.863835  0.002409 -0.304495  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6, 6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0b257a58-7097-4367-8f3b-9119e43876a6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b257a58-7097-4367-8f3b-9119e43876a6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dfcsv = pd.read_csv('House_Rent_Dataset.csv')
dfcsv
# Out:
#        Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0     18-05-2022    2  10000  1100  Ground out of 2   Super Area
# 1     13-05-2022    2  20000   800       1 out of 3   Super Area
# 2     16-05-2022    2  17000  1000       1 out of 3   Super Area
# 3     04-07-2022    2  10000   800       1 out of 2   Super Area
# 4     09-05-2022    2   7500   850       1 out of 2  Carpet Area
# ...          ...  ...    ...   ...              ...          ...
# 4741  18-05-2022    2  15000  1000       3 out of 5  Carpet Area
# 4742  15-05-2022    3  29000  2000       1 out of 4   Super Area
# 4743  10-07-2022    3  35000  1750       3 out of 5  Carpet Area
# 4744  06-07-2022    3  45000  1500     23 out of 34  Carpet Area
# 4745  04-05-2022    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
plt.figure(figsize=(5,2), dpi =200)
sns.heatmap(corr,annot=True,fmt=".2f", linewidth=.5)
plt.show()

# %%
corr = dfcsv.corr()
corr
# Out:
# <ipython-input-7-794c5c537b27>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dfcsv.corr()
#                BHK      Rent      Size  Bathroom
# BHK       1.000000  0.369718  0.716145  0.794885
# Rent      0.369718  1.000000  0.413551  0.441215
# Size      0.716145  0.413551  1.000000  0.740703
# Bathroom  0.794885  0.441215  0.740703  1.000000

# %%
pd.plotting.scatter_matrix(df, figsize=(6, 6))
plt.show()
